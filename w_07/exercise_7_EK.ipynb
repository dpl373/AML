# %% [markdown]
#     Exercise Sheet Week 7

# %%
from IPython import display

# %% [markdown]
# # Task 1

# %% [markdown]
# ## 1.b Embedding Size
#
# _(cell 26)_

# %% [markdown]
# **embed_size = 50**

# %%
display.Image('/Users/emilykruger/Library/CloudStorage/OneDrive-Personal/Dokumente/Master/05_AdvancedMachineLearning/w07_wordembeddings/embed50.png')

# %% [markdown]
# **embed_size = 100**

# %%
display.Image('/Users/emilykruger/Library/CloudStorage/OneDrive-Personal/Dokumente/Master/05_AdvancedMachineLearning/w07_wordembeddings/embed100.png')

# %% [markdown]
# **embed_size = 250**

# %%
display.Image('/Users/emilykruger/Library/CloudStorage/OneDrive-Personal/Dokumente/Master/05_AdvancedMachineLearning/w07_wordembeddings/embed250.png')

# %% [markdown]
# ## 1.c Window Size
#
# _(cell 12-19-20, embed_size = 100, noise words = 5)_

# %% [markdown]
# **window size = 2**

# %% [markdown]
# _very_ fast

# %%
display.Image('/Users/emilykruger/Library/CloudStorage/OneDrive-Personal/Dokumente/Master/05_AdvancedMachineLearning/w07_wordembeddings/window2_1.png')

# %%
display.Image('/Users/emilykruger/Library/CloudStorage/OneDrive-Personal/Dokumente/Master/05_AdvancedMachineLearning/w07_wordembeddings/window2_2.png')

# %% [markdown]
# **window size = 5**:

# %%
display.Image('/Users/emilykruger/Library/CloudStorage/OneDrive-Personal/Dokumente/Master/05_AdvancedMachineLearning/w07_wordembeddings/embed100.png')

# %%
display.Image('/Users/emilykruger/Library/CloudStorage/OneDrive-Personal/Dokumente/Master/05_AdvancedMachineLearning/w07_wordembeddings/window5.png')

# %% [markdown]
# **window size = 20**

# %% [markdown]
# _very_ slow

# %%
display.Image('/Users/emilykruger/Library/CloudStorage/OneDrive-Personal/Dokumente/Master/05_AdvancedMachineLearning/w07_wordembeddings/window20_1.png')

# %%
display.Image('/Users/emilykruger/Library/CloudStorage/OneDrive-Personal/Dokumente/Master/05_AdvancedMachineLearning/w07_wordembeddings/window20_1.png')

# %% [markdown]
# ## Task 3

# %% [markdown]
# ## 3.a
#
# - pretrained model is loaded
# - new linear layers is added for finetuning
#     - can lead to faster convergence and higher accuracy
# - higher lr for added layer

# %% [markdown]
# lr = $5 e^{-1}$

# %%
display.Image('/Users/emilykruger/Library/CloudStorage/OneDrive-Personal/Dokumente/Master/05_AdvancedMachineLearning/w07_wordembeddings/lr 5e-1.png')

# %% [markdown]
# lr = $5e^{-5}$

# %%
display.Image('/Users/emilykruger/Library/CloudStorage/OneDrive-Personal/Dokumente/Master/05_AdvancedMachineLearning/w07_wordembeddings/lr 5e-5.png')

# %% [markdown]
# lr = $5 e^{-10}$

# %%
display.Image('/Users/emilykruger/Library/CloudStorage/OneDrive-Personal/Dokumente/Master/05_AdvancedMachineLearning/w07_wordembeddings/lr 5e-10.png')

# %% [markdown]
# too small and too big lr are both bad

# %% [markdown]
# ## 3.b

# %% [markdown]
# - gradient clipping: stabilizes training, faster convergence
# - domain-specific pre-trained set: better accuracy and faster convergence
# - early stopping: prevent overfitting, faster convergence
# - lr schedules: warm-up steps and lr decay for better accuracy and faster convergence

# %% [markdown]
# # Task 5

# %% [markdown]
# _**What were the key findings in the evolution of the attention score function?**_

# %% [markdown]
# **_What is the scalability of different transformer models in training and deployment?_**
#
# highly scalable because of parallelization

# %% [markdown]
# **_What tasks have been solved well with transformer models, and where are the current key challenges?_**
#
# successes:
# - NLP tasks for widespread languages
# - Image and Audio, although not as good as text
#
# challenges:
# - actual knowledge
# - explainability

# %% [markdown]
# **_What specific decoder and encoder designs are suggested for different natural language processing, audio, and vision tasks?_**
#
# different transformers for different tasks
# - usually encoder/decoder for NLP
# - specialized transfomers for image and audio

# %% [markdown]
# **_What could be a taxonomy of the many different (efficient) transformer architectures (w.r.t. the key properties)?_**

# %% [markdown]
# **_What are key numeric and semantic metrics in the major benchmarks tests and leaderboards?_**

# %% [markdown]
# # Task 6

# %% [markdown]
# ## 6.a
#
# Deocoder hidden states:
# - keys and values: encoder final-layer hidden states at all time steps
# - query: decoder final-layer hidden state of the previous time step
#
#
# encoder hidden states:
# - ???

# %% [markdown]
# ## 6.b
#
# _(cell6)_

# %% [markdown]
# **Additive Scoring**

# %%
display.Image('/Users/emilykruger/Library/CloudStorage/OneDrive-Personal/Dokumente/Master/05_AdvancedMachineLearning/w07_wordembeddings/additive_lc.png')

# %%
display.Image('/Users/emilykruger/Library/CloudStorage/OneDrive-Personal/Dokumente/Master/05_AdvancedMachineLearning/w07_wordembeddings/additive_perf.png')

# %% [markdown]
# **Dot Product**
